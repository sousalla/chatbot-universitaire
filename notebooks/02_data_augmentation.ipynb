# %% [markdown]
# # 02 - Data Augmentation

# %%
#Importation des bibliothèques

import json
import random
import re
import pandas as pd
from pathlib import Path

print(" Bibliothèques chargées")
# Out:
#  Bibliothèques chargées

# %%
INPUT_CSV = "../data/processed/dataset_preprocessed.csv"
OUTPUT_DIR = "../data/augmented"
OUTPUT_CSV = "../data/augmented/dataset_augmented.csv"

Path(OUTPUT_DIR).mkdir(parents=True, exist_ok=True)

input_path = Path(INPUT_CSV)
if not input_path.exists():
    matches = list(Path('.').resolve().rglob('dataset_preprocessed.csv'))
    if matches:
        input_path = matches[0]
        print(f"INPUT_CSV not found at {INPUT_CSV}, using {input_path}")
    else:
        raise FileNotFoundError(f"File not found: {INPUT_CSV}")
df = pd.read_csv(input_path, sep=';', encoding='utf-8')
print(f" {len(df)} questions chargées")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 7
#       3 OUTPUT_CSV = "../data/augmented/dataset_augmented.csv"
#       5 Path(OUTPUT_DIR).mkdir(parents=True, exist_ok=True)
# ----> 7 df = pd.read_csv(INPUT_CSV, sep=';', encoding='utf-8')
#       8 print(f" {len(df)} questions chargées")
#       9 df.head()
#
# ...
